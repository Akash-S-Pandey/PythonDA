# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv("big_mart_sales.csv")
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
df.set_index("Item_Identifier",drop=True,inplace=True)

# %%
df.head()
# Out:
#                  Item_Weight Item_Fat_Content  Item_Visibility  \
# Item_Identifier
# FDA15                   9.30          Low Fat         0.016047
# DRC01                   5.92          Regular         0.019278
# FDN15                  17.50          Low Fat         0.016760
# FDX07                  19.20          Regular         0.000000
# NCD19                   8.93          Low Fat         0.000000
#
#                              Item_Type  Item_MRP Outlet_Identifier  \
# Item_Identifier
# FDA15                            Dairy  249.8092            OUT049
# DRC01                      Soft Drinks   48.2692            OUT018
# FDN15                             Meat  141.6180            OUT049
# FDX07            Fruits and Vegetables  182.0950            OUT010
# NCD19                        Household   53.8614            OUT013
#
#                  Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# Item_Identifier
# ...

# %%
df.loc[['FDA15'],['Item_Fat_Content','Item_MRP']]
# Out:
#                 Item_Fat_Content  Item_MRP
# Item_Identifier
# FDA15                    Low Fat  249.8092
# FDA15                    Low Fat  250.2092
# FDA15                    Low Fat  248.5092
# FDA15                    Low Fat  249.6092
# FDA15                    Low Fat  248.9092
# FDA15                    Low Fat  250.6092
# FDA15                    Low Fat  249.5092
# FDA15                         LF  248.8092

# %%
sample_df = pd.DataFrame({
    "gender" : ['M',"F",'M','M',"F"],
    "grade"  : ["A","A","B","B","A"],
    "marks"  : [22,21,12,14,20],
    "id"     : ['A101',"A102","A103","A104","A105"]

                         })

# %%
sample_df
# Out:
#   gender grade  marks    id
# 0      M     A     22  A101
# 1      F     A     21  A102
# 2      M     B     12  A103
# 3      M     B     14  A104
# 4      F     A     20  A105

# %%
sample_df.loc[2:4]
# Out:
#   gender grade  marks    id
# 2      M     B     12  A103
# 3      M     B     14  A104
# 4      F     A     20  A105

# %%
sample_df.iloc[2:4]
# Out:
#   gender grade  marks    id
# 2      M     B     12  A103
# 3      M     B     14  A104

# %%
sample_df=sample_df.sort_values(by=['marks'])

# %%
sample_df
# Out:
#   gender grade  marks    id
# 2      M     B     12  A103
# 3      M     B     14  A104
# 4      F     A     20  A105
# 1      F     A     21  A102
# 0      M     A     22  A101

# %%
sample_df.loc[2:4]
# Out:
#   gender grade  marks    id
# 2      M     B     12  A103
# 3      M     B     14  A104
# 4      F     A     20  A105

# %%
sample_df.iloc[2:4]
# Out:
#   gender grade  marks    id
# 4      F     A     20  A105
# 1      F     A     21  A102

# %%
sample_df.set_index('id',inplace = True)

# %%
sample_df
# Out:
#      gender grade  marks
# id
# A103      M     B     12
# A104      M     B     14
# A105      F     A     20
# A102      F     A     21
# A101      M     A     22

# %%
sample_df.loc['A104':'A101']
# Out:
#      gender grade  marks
# id
# A104      M     B     14
# A105      F     A     20
# A102      F     A     21
# A101      M     A     22

# %%
sample_df.iloc[2:4]
# Out:
#      gender grade  marks
# id
# A105      F     A     20
# A102      F     A     21

# %%
sample_df[sample_df.marks.isin([12,14])]
# Out:
#      gender grade  marks
# id
# A103      M     B     12
# A104      M     B     14

# %%
df.head()
# Out:
#                  Item_Weight Item_Fat_Content  Item_Visibility  \
# Item_Identifier
# FDA15                   9.30          Low Fat         0.016047
# DRC01                   5.92          Regular         0.019278
# FDN15                  17.50          Low Fat         0.016760
# FDX07                  19.20          Regular         0.000000
# NCD19                   8.93          Low Fat         0.000000
#
#                              Item_Type  Item_MRP Outlet_Identifier  \
# Item_Identifier
# FDA15                            Dairy  249.8092            OUT049
# DRC01                      Soft Drinks   48.2692            OUT018
# FDN15                             Meat  141.6180            OUT049
# FDX07            Fruits and Vegetables  182.0950            OUT010
# NCD19                        Household   53.8614            OUT013
#
#                  Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# Item_Identifier
# ...

# %%
dample = ['Item_Fat_Content',"Item_MRP"]
df[dample]
# Out:
#                 Item_Fat_Content  Item_MRP
# Item_Identifier
# FDA15                    Low Fat  249.8092
# DRC01                    Regular   48.2692
# FDN15                    Low Fat  141.6180
# FDX07                    Regular  182.0950
# NCD19                    Low Fat   53.8614
# ...                          ...       ...
# FDF22                    Low Fat  214.5218
# FDS36                    Regular  108.1570
# NCJ29                    Low Fat   85.1224
# FDN46                    Regular  103.1332
# DRG01                    Low Fat   75.4670
#
# [8523 rows x 2 columns]

# %%
df.loc[(df.Item_Fat_Content=='Regular') & (df.Item_MRP==103.1332),dample]
# Out:
#                 Item_Fat_Content  Item_MRP
# Item_Identifier
# FDN46                    Regular  103.1332
# FDH46                    Regular  103.1332
# FDN46                    Regular  103.1332

# %%
df.dtypes
# Out:
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# dtype: object

# %%
df.select_dtypes(object).head()
# Out:
#                 Item_Fat_Content              Item_Type Outlet_Identifier  \
# Item_Identifier
# FDA15                    Low Fat                  Dairy            OUT049
# DRC01                    Regular            Soft Drinks            OUT018
# FDN15                    Low Fat                   Meat            OUT049
# FDX07                    Regular  Fruits and Vegetables            OUT010
# NCD19                    Low Fat              Household            OUT013
#
#                 Outlet_Size Outlet_Location_Type        Outlet_Type
# Item_Identifier
# FDA15                Medium               Tier 1  Supermarket Type1
# DRC01                Medium               Tier 3  Supermarket Type2
# FDN15                Medium               Tier 1  Supermarket Type1
# FDX07                   NaN               Tier 3      Grocery Store
# NCD19                  High               Tier 3  Supermarket Type1

# %%
df.select_dtypes(float).head()
# Out:
#                  Item_Weight  Item_Visibility  Item_MRP  Item_Outlet_Sales
# Item_Identifier
# FDA15                   9.30         0.016047  249.8092          3735.1380
# DRC01                   5.92         0.019278   48.2692           443.4228
# FDN15                  17.50         0.016760  141.6180          2097.2700
# FDX07                  19.20         0.000000  182.0950           732.3800
# NCD19                   8.93         0.000000   53.8614           994.7052

# %%
df.isna().sum()
# Out:
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
df.Item_Weight.mean()
# Out:
# 12.857645184135976

# %%
df.loc[(df.Item_Weight.isna()==True),'Item_Weight'] = df.Item_Weight.mean()

# %%
df.head()
# Out:
#                  Item_Weight Item_Fat_Content  Item_Visibility  \
# Item_Identifier
# FDA15                   9.30          Low Fat         0.016047
# DRC01                   5.92          Regular         0.019278
# FDN15                  17.50          Low Fat         0.016760
# FDX07                  19.20          Regular         0.000000
# NCD19                   8.93          Low Fat         0.000000
#
#                              Item_Type  Item_MRP Outlet_Identifier  \
# Item_Identifier
# FDA15                            Dairy  249.8092            OUT049
# DRC01                      Soft Drinks   48.2692            OUT018
# FDN15                             Meat  141.6180            OUT049
# FDX07            Fruits and Vegetables  182.0950            OUT010
# NCD19                        Household   53.8614            OUT013
#
#                  Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# Item_Identifier
# ...

# %%
df.Outlet_Size.mode()
# Out:
# 0    Medium
# dtype: object

# %%
df.Outlet_Size.value_counts()
# Out:
# Medium    2793
# Small     2388
# High       932
# Name: Outlet_Size, dtype: int64

# %%
df.Outlet_Size.mode()
# Out:
# 0    Medium
# dtype: object

# %%
df.loc[(df.Outlet_Size.isna()==True),'Outlet_Size'] = 'Medium'

# %%
df.head()
# Out:
#                  Item_Weight Item_Fat_Content  Item_Visibility  \
# Item_Identifier
# FDA15                   9.30          Low Fat         0.016047
# DRC01                   5.92          Regular         0.019278
# FDN15                  17.50          Low Fat         0.016760
# FDX07                  19.20          Regular         0.000000
# NCD19                   8.93          Low Fat         0.000000
#
#                              Item_Type  Item_MRP Outlet_Identifier  \
# Item_Identifier
# FDA15                            Dairy  249.8092            OUT049
# DRC01                      Soft Drinks   48.2692            OUT018
# FDN15                             Meat  141.6180            OUT049
# FDX07            Fruits and Vegetables  182.0950            OUT010
# NCD19                        Household   53.8614            OUT013
#
#                  Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# Item_Identifier
# ...

# %%
df.Outlet_Size.fillna('Medium',inplace=True)

# %%
df.head()
# Out:
#                  Item_Weight Item_Fat_Content  Item_Visibility  \
# Item_Identifier
# FDA15                   9.30          Low Fat         0.016047
# DRC01                   5.92          Regular         0.019278
# FDN15                  17.50          Low Fat         0.016760
# FDX07                  19.20          Regular         0.000000
# NCD19                   8.93          Low Fat         0.000000
#
#                              Item_Type  Item_MRP Outlet_Identifier  \
# Item_Identifier
# FDA15                            Dairy  249.8092            OUT049
# DRC01                      Soft Drinks   48.2692            OUT018
# FDN15                             Meat  141.6180            OUT049
# FDX07            Fruits and Vegetables  182.0950            OUT010
# NCD19                        Household   53.8614            OUT013
#
#                  Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# Item_Identifier
# ...

# %%
df.Item_Fat_Content.value_counts()
# Out:
# Low Fat    5089
# Regular    2889
# LF          316
# reg         117
# low fat     112
# Name: Item_Fat_Content, dtype: int64

# %%
Item = {
    "Low Fat"  :  "LF",
    "Regular"  :  "R",
    "LF"       :  "LF",
    "reg "     :  "R",
    "low fat"  :  "LF"
}

# %%
df.Item_Fat_Content.map(Item)
# Out:
# Item_Identifier
# FDA15    LF
# DRC01     R
# FDN15    LF
# FDX07     R
# NCD19    LF
#          ..
# FDF22    LF
# FDS36     R
# NCJ29    LF
# FDN46     R
# DRG01    LF
# Name: Item_Fat_Content, Length: 8523, dtype: object

# %%
df.Item_Fat_Content = df.Item_Fat_Content.map(Item)

# %%
df.Item_Fat_Content.value_counts()
# Out:
# LF    5517
# R     2889
# Name: Item_Fat_Content, dtype: int64

# %%
df.Item_MRP.apply(lambda x : x/74)
# Out:
# Item_Identifier
# FDA15    3.375800
# DRC01    0.652286
# FDN15    1.913757
# FDX07    2.460743
# NCD19    0.727857
#            ...
# FDF22    2.898943
# FDS36    1.461581
# NCJ29    1.150303
# FDN46    1.393692
# DRG01    1.019824
# Name: Item_MRP, Length: 8523, dtype: float64

# %%
def convert(price):
    price = price/74
    price = price + 1.8
    return price

# %%
df["Item_MRP_IN_USD_UPDATED"] = df.Item_MRP.apply(lambda x : convert(x))

# %%
df["Item_MRP_IN_USD"] = df.Item_MRP.apply(lambda x : x/74)

# %%
df.head()
# Out:
#                  Item_Weight Item_Fat_Content  Item_Visibility  \
# Item_Identifier
# FDA15                   9.30               LF         0.016047
# DRC01                   5.92                R         0.019278
# FDN15                  17.50               LF         0.016760
# FDX07                  19.20                R         0.000000
# NCD19                   8.93               LF         0.000000
#
#                              Item_Type  Item_MRP Outlet_Identifier  \
# Item_Identifier
# FDA15                            Dairy  249.8092            OUT049
# DRC01                      Soft Drinks   48.2692            OUT018
# FDN15                             Meat  141.6180            OUT049
# FDX07            Fruits and Vegetables  182.0950            OUT010
# NCD19                        Household   53.8614            OUT013
#
#                  Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# Item_Identifier
# ...

# %%
df[['Item_MRP',"Item_MRP_IN_USD","Item_MRP_IN_USD_UPDATED"]]
# Out:
#                  Item_MRP  Item_MRP_IN_USD  Item_MRP_IN_USD_UPDATED
# Item_Identifier
# FDA15            249.8092         3.375800                 5.175800
# DRC01             48.2692         0.652286                 2.452286
# FDN15            141.6180         1.913757                 3.713757
# FDX07            182.0950         2.460743                 4.260743
# NCD19             53.8614         0.727857                 2.527857
# ...                   ...              ...                      ...
# FDF22            214.5218         2.898943                 4.698943
# FDS36            108.1570         1.461581                 3.261581
# NCJ29             85.1224         1.150303                 2.950303
# FDN46            103.1332         1.393692                 3.193692
# DRG01             75.4670         1.019824                 2.819824
#
# [8523 rows x 3 columns]

# %% [markdown]
# encoding data i 1,0

# %%
data = pd.get_dummies(df)

# %%
data.head()
# Out:
#                  Item_Weight  Item_Visibility  Item_MRP  \
# Item_Identifier
# FDA15                   9.30         0.016047  249.8092
# DRC01                   5.92         0.019278   48.2692
# FDN15                  17.50         0.016760  141.6180
# FDX07                  19.20         0.000000  182.0950
# NCD19                   8.93         0.000000   53.8614
#
#                  Outlet_Establishment_Year  Item_Outlet_Sales  \
# Item_Identifier
# FDA15                                 1999          3735.1380
# DRC01                                 2009           443.4228
# FDN15                                 1999          2097.2700
# FDX07                                 1998           732.3800
# NCD19                                 1987           994.7052
#
#                  Item_MRP_IN_USD_UPDATED  Item_MRP_IN_USD  \
# Item_Identifier
# FDA15                           5.175800         3.375800
# DRC01                           2.452286         0.652286
# ...

# %%
import pandas as pd
import datetime
data = pd.read_csv("Data/Time series Data/time_series.csv")

# %%
data.head()
# Out:
#    ID          Datetime  Count
# 0   0  25-08-2012 00:00      8
# 1   1  25-08-2012 01:00      2
# 2   2  25-08-2012 02:00      6
# 3   3  25-08-2012 03:00      2
# 4   4  25-08-2012 04:00      2

# %%
data.dtypes
# Out:
# ID           int64
# Datetime    object
# Count        int64
# dtype: object

# %%
data.Datetime = pd.to_datetime(data.Datetime)

# %%
data.dtypes
# Out:
# ID                   int64
# Datetime    datetime64[ns]
# Count                int64
# dtype: object

# %%
data.Datetime.apply(lambda x : x.day_name())
# Out:
# 0        Saturday
# 1        Saturday
# 2        Saturday
# 3        Saturday
# 4        Saturday
#            ...
# 18283    Thursday
# 18284    Thursday
# 18285    Thursday
# 18286    Thursday
# 18287    Thursday
# Name: Datetime, Length: 18288, dtype: object

# %%
data.Datetime.apply(lambda x : x.month_name())
# Out:
# 0           August
# 1           August
# 2           August
# 3           August
# 4           August
#            ...
# 18283    September
# 18284    September
# 18285    September
# 18286    September
# 18287    September
# Name: Datetime, Length: 18288, dtype: object

# %%
data3 = pd.read_csv("Data/Time series Data/time_series_2.csv")
data3
# Out:
#           ID      Datetime  Count
# 0          0  25 Aug 2012       8
# 1          1  25 Aug 2012       2
# 2          2  25 Aug 2012       6
# 3          3  25 Aug 2012       2
# 4          4  25 Aug 2012       2
# ...      ...           ...    ...
# 18283  18283  25 Sep 2014     868
# 18284  18284  25 Sep 2014     732
# 18285  18285  25 Sep 2014     702
# 18286  18286  25 Sep 2014     580
# 18287  18287  25 Sep 2014     534
#
# [18288 rows x 3 columns]

# %%
data3.shape
# Out:
# (18288, 3)

# %%
data3.head()
# Out:
#    ID      Datetime  Count
# 0   0  25 Aug 2012       8
# 1   1  25 Aug 2012       2
# 2   2  25 Aug 2012       6
# 3   3  25 Aug 2012       2
# 4   4  25 Aug 2012       2

# %%
data3.dtypes
# Out:
# ID           int64
# Datetime    object
# Count        int64
# dtype: object

# %%
data3.Datetime = pd.to_datetime(data3.Datetime)

# %%
data3.dtypes
# Out:
# ID                   int64
# Datetime    datetime64[ns]
# Count                int64
# dtype: object

# %%
data3
# Out:
#           ID   Datetime  Count
# 0          0 2012-08-25      8
# 1          1 2012-08-25      2
# 2          2 2012-08-25      6
# 3          3 2012-08-25      2
# 4          4 2012-08-25      2
# ...      ...        ...    ...
# 18283  18283 2014-09-25    868
# 18284  18284 2014-09-25    732
# 18285  18285 2014-09-25    702
# 18286  18286 2014-09-25    580
# 18287  18287 2014-09-25    534
#
# [18288 rows x 3 columns]

# %%
data3['month'] = data3.Datetime.dt.month
data3['month_name'] = data3.Datetime.dt.month_name()

# %%
data3.head()
# Out:
#    ID   Datetime  Count  month month_name
# 0   0 2012-08-25      8      8     August
# 1   1 2012-08-25      2      8     August
# 2   2 2012-08-25      6      8     August
# 3   3 2012-08-25      2      8     August
# 4   4 2012-08-25      2      8     August

# %%
data3['day_name'] = data3.Datetime.dt.day_name()
data3['day_of_week'] = data3.Datetime.dt.dayofweek
data3['day_of_year'] = data3.Datetime.dt.dayofyear

# %%
data3.head()
# Out:
#    ID   Datetime  Count  month month_name  day_name  day_of_week  day_of_year
# 0   0 2012-08-25      8      8     August  Saturday            5          238
# 1   1 2012-08-25      2      8     August  Saturday            5          238
# 2   2 2012-08-25      6      8     August  Saturday            5          238
# 3   3 2012-08-25      2      8     August  Saturday            5          238
# 4   4 2012-08-25      2      8     August  Saturday            5          238

# %%
data3['today'] = pd.to_datetime(datetime.date.today())

# %%
data3.head()
# Out:
#    ID   Datetime  Count  month month_name  day_name  day_of_week  day_of_year  \
# 0   0 2012-08-25      8      8     August  Saturday            5          238
# 1   1 2012-08-25      2      8     August  Saturday            5          238
# 2   2 2012-08-25      6      8     August  Saturday            5          238
# 3   3 2012-08-25      2      8     August  Saturday            5          238
# 4   4 2012-08-25      2      8     August  Saturday            5          238
#
#        today
# 0 2022-01-21
# 1 2022-01-21
# 2 2022-01-21
# 3 2022-01-21
# 4 2022-01-21

# %%
date_difference = data3['today'] - data3['Datetime']

# %%
date_difference.head()
# Out:
# 0   3436 days
# 1   3436 days
# 2   3436 days
# 3   3436 days
# 4   3436 days
# dtype: timedelta64[ns]

# %%
date_difference.apply(lambda x : x.days)
# Out:
# 0        3436
# 1        3436
# 2        3436
# 3        3436
# 4        3436
#          ...
# 18283    2675
# 18284    2675
# 18285    2675
# 18286    2675
# 18287    2675
# Length: 18288, dtype: int64

# %%
data3['date_difference'] = date_difference.apply(lambda x : x.days)

# %%
data3.head()
# Out:
#    ID   Datetime  Count  month month_name  day_name  day_of_week  day_of_year  \
# 0   0 2012-08-25      8      8     August  Saturday            5          238
# 1   1 2012-08-25      2      8     August  Saturday            5          238
# 2   2 2012-08-25      6      8     August  Saturday            5          238
# 3   3 2012-08-25      2      8     August  Saturday            5          238
# 4   4 2012-08-25      2      8     August  Saturday            5          238
#
#        today  date_difference
# 0 2022-01-21             3436
# 1 2022-01-21             3436
# 2 2022-01-21             3436
# 3 2022-01-21             3436
# 4 2022-01-21             3436

# %% [markdown]
# time zone of ahia calcutta

# %%
data3['asia_calcutta'] = data3.Datetime.dt.tz_localize('Asia/Calcutta')

# %%
data3.head()
# Out:
#    ID   Datetime  Count  month month_name  day_name  day_of_week  day_of_year  \
# 0   0 2012-08-25      8      8     August  Saturday            5          238
# 1   1 2012-08-25      2      8     August  Saturday            5          238
# 2   2 2012-08-25      6      8     August  Saturday            5          238
# 3   3 2012-08-25      2      8     August  Saturday            5          238
# 4   4 2012-08-25      2      8     August  Saturday            5          238
#
#        today  date_difference             asia_calcutta
# 0 2022-01-21             3436 2012-08-25 00:00:00+05:30
# 1 2022-01-21             3436 2012-08-25 00:00:00+05:30
# 2 2022-01-21             3436 2012-08-25 00:00:00+05:30
# 3 2022-01-21             3436 2012-08-25 00:00:00+05:30
# 4 2022-01-21             3436 2012-08-25 00:00:00+05:30

# %%
data3['UTC'] = data3.Datetime.dt.tz_localize('UTC')

# %%
data3[['UTC',"asia_calcutta"]]
# Out:
#                             UTC             asia_calcutta
# 0     2012-08-25 00:00:00+00:00 2012-08-25 00:00:00+05:30
# 1     2012-08-25 00:00:00+00:00 2012-08-25 00:00:00+05:30
# 2     2012-08-25 00:00:00+00:00 2012-08-25 00:00:00+05:30
# 3     2012-08-25 00:00:00+00:00 2012-08-25 00:00:00+05:30
# 4     2012-08-25 00:00:00+00:00 2012-08-25 00:00:00+05:30
# ...                         ...                       ...
# 18283 2014-09-25 00:00:00+00:00 2014-09-25 00:00:00+05:30
# 18284 2014-09-25 00:00:00+00:00 2014-09-25 00:00:00+05:30
# 18285 2014-09-25 00:00:00+00:00 2014-09-25 00:00:00+05:30
# 18286 2014-09-25 00:00:00+00:00 2014-09-25 00:00:00+05:30
# 18287 2014-09-25 00:00:00+00:00 2014-09-25 00:00:00+05:30
#
# [18288 rows x 2 columns]

# %%
data3["asia_calcutta"][18285]
# Out:
# Timestamp('2014-09-25 00:00:00+0530', tz='Asia/Calcutta')

# %%
df = pd.read_csv('Data\Time series Data\data_with_timestamp.csv')
df.head()
# Out:
#    ID   timestamp  Count
# 0   0  1345852800      8
# 1   1  1345856400      2
# 2   2  1345860000      6
# 3   3  1345863600      2
# 4   4  1345867200      2

# %%
df.timestamp = pd.to_datetime(df.timestamp,unit='s')

# %%
df.head()
# Out:
#    ID           timestamp  Count
# 0   0 2012-08-25 00:00:00      8
# 1   1 2012-08-25 01:00:00      2
# 2   2 2012-08-25 02:00:00      6
# 3   3 2012-08-25 03:00:00      2
# 4   4 2012-08-25 04:00:00      2
