# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as pyt
import seaborn as sn
import jovian

# %%
import glob

# %%
for directory in glob.glob("Data/Exel/datasets/*"):
    print(directory)
# Out:
# Data/Exel/datasets\big_mart_sales.xlsx
# Data/Exel/datasets\big_mart_sales_comments.xlsx
# Data/Exel/datasets\big_mart_sales_with_multiple_sheets.xlsx
# Data/Exel/datasets\multi-directory-excel

# %%
data_frame_list = []
for directory in glob.glob("Data/sales/*"):
     data_frame_list.append(pd.read_csv(directory))

# %%
df = pd.read_excel('Data/Exel/datasets/big_mart_sales.xlsx')
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
df.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=8523, step=1)

# %% [markdown]
# dealing  multiple sheets

# %%
df1 = pd.read_excel("Data/Exel/datasets/big_mart_sales_with_multiple_sheets.xlsx",sheet_name='1987')
df1.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           NCD19         8.93          Low Fat         0.000000
# 1           FDO10        13.65          Regular         0.012741
# 2           FDF32        16.35          Low Fat         0.068024
# 3           FDN22        18.85          Regular         0.138190
# 4           DRJ59        11.65          low fat         0.019356
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0              Household   53.8614            OUT013
# 1            Snack Foods   57.6588            OUT013
# 2  Fruits and Vegetables  196.4426            OUT013
# 3            Snack Foods  250.8724            OUT013
# 4            Hard Drinks   39.1164            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                     1987.0        High               Tier 3
# 1                     1987.0        High               Tier 3
# ...

# %%
df3 = pd.read_excel("Data/Exel/datasets/big_mart_sales_with_multiple_sheets.xlsx",sheet_name='1985')
df3.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDP10          NaN          Low Fat         0.127470
# 1           DRI11          NaN          Low Fat         0.034238
# 2           FDW12          NaN          Regular         0.035400
# 3           FDC37          NaN          Low Fat         0.057557
# 4           FDC14          NaN          Regular         0.072222
#
#       Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 0   Snack Foods  107.7622            OUT027                     1985.0
# 1   Hard Drinks  113.2834            OUT027                     1985.0
# 2  Baking Goods  144.5444            OUT027                     1985.0
# 3  Baking Goods  107.6938            OUT019                     1985.0
# 4        Canned   43.6454            OUT019                     1985.0
#
#   Outlet_Size Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 0      Medium               Tier 3  Supermarket Type3          4022.7636
# ...

# %%
df4 = pd.read_excel("Data/Exel/datasets/big_mart_sales_with_multiple_sheets.xlsx",sheet_name='1997')
df4.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA03        18.50          Regular         0.045464
# 1           FDS46        17.60          Regular         0.047257
# 2           FDP49         9.00          Regular         0.069089
# 3           FDR28        13.85          Regular         0.025896
# 4           DRH01        17.50          Low Fat         0.097904
#
#       Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 0         Dairy  144.1102            OUT046                     1997.0
# 1   Snack Foods  119.6782            OUT046                     1997.0
# 2     Breakfast   56.3614            OUT046                     1997.0
# 3  Frozen Foods  165.0210            OUT046                     1997.0
# 4   Soft Drinks  174.8738            OUT046                     1997.0
#
#   Outlet_Size Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 0       Small               Tier 1  Supermarket Type1          2187.1530
# ...

# %%
df1.shape
# Out:
# (932, 12)

# %%
df3.shape
# Out:
# (1463, 12)

# %%
df4.shape
# Out:
# (930, 12)

# %%
# add the heet

data = [df1,df3,df4]
df = pd.concat(data)

# %%
df
# Out:
#     Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0             NCD19        8.930          Low Fat         0.000000
# 1             FDO10       13.650          Regular         0.012741
# 2             FDF32       16.350          Low Fat         0.068024
# 3             FDN22       18.850          Regular         0.138190
# 4             DRJ59       11.650          low fat         0.019356
# ..              ...          ...              ...              ...
# 925           FDC28        7.905          Low Fat         0.054987
# 926           FDB17       13.150          Low Fat         0.036672
# 927           FDT34        9.300          Low Fat         0.174350
# 928           FDF53       20.750              reg         0.083607
# 929           DRG01       14.800          Low Fat         0.044878
#
#                  Item_Type  Item_MRP Outlet_Identifier  \
# 0                Household   53.8614            OUT013
# ...

# %%
df.Outlet_Establishment_Year.unique()
# Out:
# array([1987., 1985., 1997.])

# %%
df.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
df.Item_Outlet_Sales.unique()
# Out:
# array([ 994.7052,  343.5528, 1977.426 , ..., 1844.9318, 2419.5172,
#        3608.636 ])

# %%
x = pd.read_json('Data/jon/datasets/simple.json')

# %%
x.head()
# Out:
#       name  age grade
# 0    Andew   12     A
# 1   Bhuvan   18     B
# 2  Clinton   11     A
# 3    Drake   12     C
# 4    Eisha   13     B

# %%
import json
from pprint import pprint

# %%
with open('Data/jon/datasets/nested.json') as f:
     formal = json.load(f)

# %%
pprint(formal)
# Out:
# [{'details': {'age': 12, 'grade': 'A', 'name': 'Andew'},
#   'student_roll_no': 101},
#  {'details': {'age': 18, 'grade': 'B', 'name': 'Bhuvan'},
#   'student_roll_no': 102},
#  {'details': {'age': 11, 'grade': 'A', 'name': 'Clinton'},
#   'student_roll_no': 103},
#  {'details': {'age': 12, 'grade': 'C', 'name': 'Drake'},
#   'student_roll_no': 104},
#  {'details': {'age': 13, 'grade': 'B', 'name': 'Eisha'},
#   'student_roll_no': 105},
#  {'details': {'age': 22, 'grade': 'C', 'name': 'Farhan'},
#   'student_roll_no': 106},
#  {'details': {'age': 11, 'grade': 'A', 'name': 'Garima'},
#   'student_roll_no': 107},
#  {'details': {'age': 19, 'grade': 'A', 'name': 'Himanshu'},
#   'student_roll_no': 108},
#  {'details': {'age': 10, 'grade': 'D', 'name': 'Ishaan'},
#   'student_roll_no': 109},
#  {'details': {'age': 9, 'grade': 'B', 'name': 'Jason'}, 'student_roll_no': 110}]

# %%
data = formal[0]

# %%
data
# Out:
# {'student_roll_no': 101, 'details': {'name': 'Andew', 'age': 12, 'grade': 'A'}}

# %%
data['details']['age']
# Out:
# 12

# %%
for data in formal:
    print(data['details']['age'])
# Out:
# 12
# 18
# 11
# 12
# 13
# 22
# 11
# 19
# 10
# 9

# %%
filtered_data = []
for data in  formal:
    filter_variable = {}
    if data['details']['age']>15:
        filter_variable['age'] = data['details']['age']
        filter_variable['name'] = data['details']['name']
        filtered_data.append(filter_variable)

# %%
filtered_data
# Out:
# [{'age': 18, 'name': 'Bhuvan'},
#  {'age': 22, 'name': 'Farhan'},
#  {'age': 19, 'name': 'Himanshu'}]

# %% [markdown]
# to make a new file for filtered data

# %%
with open('Data/jon/datasets/filter.json','w') as f:
     json.dump(filtered_data,f,indent=4)

# %%
df = pd.read_csv('Data/sales/2020.csv')
df.head(10)
# Out:
#                               Region                           Country  \
# 0                 Sub-Saharan Africa                              Chad
# 1                             Europe                            Latvia
# 2       Middle East and North Africa                          Pakistan
# 3                 Sub-Saharan Africa  Democratic Republic of the Congo
# 4                             Europe                    Czech Republic
# 5                 Sub-Saharan Africa                      South Africa
# 6                               Asia                              Laos
# 7                               Asia                             China
# 8                 Sub-Saharan Africa                           Eritrea
# 9  Central America and the Caribbean                             Haiti
#
#          Item Type Sales Channel Order Priority  Order Date   Order ID  \
# 0  Office Supplies        Online              L   1/27/2011  292494523
# ...

# %%
df.shape
# Out:
# (10000, 14)

# %%
df.columns
# Out:
# Index(['Region', 'Country', 'Item Type', 'Sales Channel', 'Order Priority',
#        'Order ID', 'Ship Date', 'Units Sold', 'Unit Price', 'Unit Cost',
#        'Total Revenue', 'Total Cost', 'Total Profit'],
#       dtype='object')

# %%
import random
ind = [random.randint(1,10000) for i in range(10000)]

# %% [markdown]
# Method To

# %%
df.index = ind

# %%
df.head()
# Out:
#                                  Region                           Country  \
# Order ID
# 292494523            Sub-Saharan Africa                              Chad
# 361825549                        Europe                            Latvia
# 141515767  Middle East and North Africa                          Pakistan
# 500364005            Sub-Saharan Africa  Democratic Republic of the Congo
# 127481591                        Europe                    Czech Republic
#
#                  Item Type Sales Channel Order Priority  Ship Date  \
# Order ID
# 292494523  Office Supplies        Online              L  2/12/2011
# 361825549        Beverages        Online              C  1/23/2016
# 141515767       Vegetables       Offline              C   2/1/2011
# 500364005        Household        Online              C  10/6/2012
# 127481591        Beverages        Online              C  12/5/2015
#
#            Units Sold  Unit Price  Unit Cost  Total Revenue  Total Cost  \
# Order ID
# ...

# %%
df.index
# Out:
# Int64Index([292494523, 361825549, 141515767, 500364005, 127481591, 482292354,
#             844532620, 564251220, 411809480, 327881228,
#             ...
#             651942288, 579082763, 521562898, 420056521, 735549962, 199342048,
#             763044106, 848579967, 298185956, 824410903],
#            dtype='int64', name='Order ID', length=10000)

# %%
df.loc[292494523]
# Out:
# Region            Sub-Saharan Africa
# Country                         Chad
# Item Type            Office Supplies
# Sales Channel                 Online
# Order Priority                     L
# Ship Date                  2/12/2011
# Units Sold                      4484
# Unit Price                    651.21
# Unit Cost                     524.96
# Total Revenue             2920025.64
# Total Cost                2353920.64
# Total Profit                566105.0
# Name: 292494523, dtype: object

# %%
df.reset_index(inplace=True)

# %%
df.head()
# Out:
#     Order ID                        Region                           Country  \
# 0  292494523            Sub-Saharan Africa                              Chad
# 1  361825549                        Europe                            Latvia
# 2  141515767  Middle East and North Africa                          Pakistan
# 3  500364005            Sub-Saharan Africa  Democratic Republic of the Congo
# 4  127481591                        Europe                    Czech Republic
#
#          Item Type Sales Channel Order Priority  Ship Date  Units Sold  \
# 0  Office Supplies        Online              L  2/12/2011        4484
# 1        Beverages        Online              C  1/23/2016        1075
# 2       Vegetables       Offline              C   2/1/2011        6515
# 3        Household        Online              C  10/6/2012        7683
# 4        Beverages        Online              C  12/5/2015        3491
#
#    Unit Price  Unit Cost  Total Revenue  Total Cost  Total Profit
# ...

# %%
y = df[df['Country'] == 'Pakistan']
y.head()
# Out:
#        Order ID                        Region   Country        Item Type  \
# 2     141515767  Middle East and North Africa  Pakistan       Vegetables
# 44    156722390  Middle East and North Africa  Pakistan        Household
# 222   408248364  Middle East and North Africa  Pakistan       Vegetables
# 506   997786748  Middle East and North Africa  Pakistan  Office Supplies
# 1180  287727487  Middle East and North Africa  Pakistan        Baby Food
#
#      Sales Channel Order Priority  Ship Date  Units Sold  Unit Price  \
# 2          Offline              C   2/1/2011        6515      154.06
# 44         Offline              M   8/1/2012        6493      668.27
# 222        Offline              C  7/16/2016        8618      154.06
# 506         Online              L  2/12/2012        6127      651.21
# 1180        Online              C   1/5/2011        3812      255.28
#
#       Unit Cost  Total Revenue  Total Cost  Total Profit
# ...
